# %% [markdown]
# <a href="https://colab.research.google.com/github/jsansao/teic-20231/blob/main/TEIC_Tarefa5_CIFAR_10_Solucao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarefa 5 (CIFAR-10 com recursos para melhorar overfitting e acurácia)
#
# Para este exercício, vamos usar o dataset CIFAR-10. O CIFAR-10 consiste de 60000 imagens coloridas (32 x 32 pixels) de 10 objetos distintos. O conjunto de treinamento tem 50000 imagens e o conjunto de teste tem 10000.
#
# As classes são:
#
#
# * Avião
# * Automóvel
# * Pássaro
# * Gato
# * Cervo
# * Cão
# * Sapo
# * Cavalo
# * Navio
# * Caminhão
#
# Vamos comparar a evolução da acurácia de treinamento e validação, considerando a inclusão de diversos recursos no treinamento das CNN.

# %% [markdown]
# # 1. Linha de base

# %%
import tensorflow as tf



class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9):
      print("\nAtingiu acc > 0.9, cancelando treinamento")
      self.model.stop_training = True

callbacks = myCallback()

mnist = tf.keras.datasets.cifar10
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(50000, 32, 32, 3)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 32, 32, 3)
test_images=test_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(32, 32, 3)),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')

])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#model.fit(training_images, training_labels, epochs=10, callbacks=[callbacks])

history = model.fit(training_images, training_labels,
                              validation_data=(test_images, test_labels),                              
                              epochs=10,
                              verbose=2)


test_loss, test_acc = model.evaluate(test_images, test_labels)
print(test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step
# Epoch 1/10
# 1563/1563 - 19s - loss: 1.5253 - accuracy: 0.4422 - val_loss: 1.2397 - val_accuracy: 0.5520 - 19s/epoch - 12ms/step
# Epoch 2/10
# 1563/1563 - 7s - loss: 1.1731 - accuracy: 0.5831 - val_loss: 1.2031 - val_accuracy: 0.5775 - 7s/epoch - 5ms/step
# Epoch 3/10
# 1563/1563 - 7s - loss: 1.0382 - accuracy: 0.6347 - val_loss: 1.0470 - val_accuracy: 0.6351 - 7s/epoch - 4ms/step
# Epoch 4/10
# 1563/1563 - 6s - loss: 0.9360 - accuracy: 0.6721 - val_loss: 0.9906 - val_accuracy: 0.6557 - 6s/epoch - 4ms/step
# Epoch 5/10
# 1563/1563 - 7s - loss: 0.8614 - accuracy: 0.6991 - val_loss: 0.9473 - val_accuracy: 0.6722 - 7s/epoch - 4ms/step
# Epoch 6/10
# 1563/1563 - 6s - loss: 0.7998 - accuracy: 0.7220 - val_loss: 0.9088 - val_accuracy: 0.6845 - 6s/epoch - 4ms/step
# Epoch 7/10
# 1563/1563 - 7s - loss: 0.7471 - accuracy: 0.7385 - val_loss: 0.8783 - val_accuracy: 0.6976 - 7s/epoch - 5ms/step
# Epoch 8/10
# 1563/1563 - 6s - loss: 0.6999 - accuracy: 0.7558 - val_loss: 0.9165 - val_accuracy: 0.6876 - 6s/epoch - 4ms/step
# Epoch 9/10
# 1563/1563 - 7s - loss: 0.6605 - accuracy: 0.7685 - val_loss: 0.8611 - val_accuracy: 0.7056 - 7s/epoch - 4ms/step
# Epoch 10/10
# 1563/1563 - 6s - loss: 0.6257 - accuracy: 0.7797 - val_loss: 0.8819 - val_accuracy: 0.7052 - 6s/epoch - 4ms/step
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8819 - accuracy: 0.7052
# 0.7052000164985657

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # 2. Image Augmentation

# %%
import tensorflow as tf


import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers, optimizers
import numpy as np
from matplotlib import pyplot



cifar10 = tf.keras.datasets.cifar10

num_classes = 10


(x_train, y_train), (x_test, y_test) = cifar10.load_data()


y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)


datagen_train = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

datagen_test = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)
# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen_train.fit(x_train)
datagen_test.fit(x_test)


# build the model

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(32, 32, 3)),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')

])


model.summary()


model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(datagen_train.flow(x_train, y_train),
         validation_data=datagen_test.flow(x_test, y_test),
         epochs=10)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 90,506
# Trainable params: 90,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.6492 - accuracy: 0.3978 - val_loss: 1.4835 - val_accuracy: 0.4618
# Epoch 2/10
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.3562 - accuracy: 0.5147 - val_loss: 1.3748 - val_accuracy: 0.5193
# Epoch 3/10
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.2383 - accuracy: 0.5619 - val_loss: 1.1975 - val_accuracy: 0.5735
# Epoch 4/10
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.1711 - accuracy: 0.5884 - val_loss: 1.1654 - val_accuracy: 0.5852
# Epoch 5/10
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.1343 - accuracy: 0.6051 - val_loss: 1.1667 - val_accuracy: 0.5955
# Epoch 6/10
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.1123 - accuracy: 0.6153 - val_loss: 1.1250 - val_accuracy: 0.6035
# Epoch 7/10
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.0990 - accuracy: 0.6207 - val_loss: 1.0884 - val_accuracy: 0.6295
# Epoch 8/10
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.0976 - accuracy: 0.6240 - val_loss: 1.2563 - val_accuracy: 0.5640
# Epoch 9/10
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.0880 - accuracy: 0.6303 - val_loss: 1.0786 - val_accuracy: 0.6256
# Epoch 10/10
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.0910 - accuracy: 0.6285 - val_loss: 1.1574 - val_accuracy: 0.6032

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # 3. Inclusão de dropout

# %%
import tensorflow as tf


import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers, optimizers
import numpy as np
from matplotlib import pyplot



cifar10 = tf.keras.datasets.cifar10

num_classes = 10


(x_train, y_train), (x_test, y_test) = cifar10.load_data()


y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)


datagen_train = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

datagen_test = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)
# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen_train.fit(x_train)
datagen_test.fit(x_test)


# build the model

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(32, 32, 3)),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')

])


model.summary()


model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(datagen_train.flow(x_train, y_train),
         validation_data=datagen_test.flow(x_test, y_test),
         epochs=10)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_8 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 2, 2, 64)          0
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 90,506
# Trainable params: 90,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 41s 25ms/step - loss: 1.7311 - accuracy: 0.3589 - val_loss: 1.4651 - val_accuracy: 0.4569
# Epoch 2/10
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.4612 - accuracy: 0.4736 - val_loss: 1.3973 - val_accuracy: 0.5026
# Epoch 3/10
# 1563/1563 [==============================] - 46s 29ms/step - loss: 1.3614 - accuracy: 0.5156 - val_loss: 1.2434 - val_accuracy: 0.5605
# Epoch 4/10
# 1563/1563 [==============================] - 43s 27ms/step - loss: 1.2981 - accuracy: 0.5397 - val_loss: 1.1758 - val_accuracy: 0.5834
# Epoch 5/10
# 1563/1563 [==============================] - 43s 27ms/step - loss: 1.2678 - accuracy: 0.5534 - val_loss: 1.1899 - val_accuracy: 0.5769
# Epoch 6/10
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.2419 - accuracy: 0.5675 - val_loss: 1.1276 - val_accuracy: 0.6132
# Epoch 7/10
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.2304 - accuracy: 0.5745 - val_loss: 1.1242 - val_accuracy: 0.6166
# Epoch 8/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.2430 - accuracy: 0.5729 - val_loss: 1.1354 - val_accuracy: 0.6116
# Epoch 9/10
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.2457 - accuracy: 0.5728 - val_loss: 1.2159 - val_accuracy: 0.5813
# Epoch 10/10
# 1563/1563 [==============================] - 46s 29ms/step - loss: 1.2504 - accuracy: 0.5738 - val_loss: 1.1138 - val_accuracy: 0.6155

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # CIFAR-10 90%
#
# Vamos abordar o problema com ampliação, dropout, regularização, normalização de lote e 6 camadas convolucionais.

# %%
import tensorflow as tf


import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers, optimizers
import numpy as np
from matplotlib import pyplot



cifar10 = tf.keras.datasets.cifar10

num_classes = 10


(x_train, y_train), (x_test, y_test) = cifar10.load_data()


y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

datagen_train = ImageDataGenerator(featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=True,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)


datagen_test = ImageDataGenerator(featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=True,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)


# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen_train.fit(x_train)
datagen_test.fit(x_test)

# build the model

# number of hidden units variable 
# we are declaring this variable here and use it in our CONV layers to make it easier to update from one place
base_hidden_units = 32

# l2 regularization hyperparameter
weight_decay = 1e-4 

# instantiate an empty sequential model 
model = Sequential()

# CONV1
# notice that we defined the input_shape here because this is the first CONV layer. 
# we don’t need to do that for the remaining layers
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV2
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# CONV3
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV4
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

# CONV5
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV6
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# FC7
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# print model summary
model.summary()

opt = tf.keras.optimizers.RMSprop(learning_rate=0.0003) # removendo o decay por ter sido removido do RMSprop do keras

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 64
epochs=125

history = model.fit(datagen_train.flow(x_train, y_train,batch_size=batch_size),
         validation_data=datagen_test.flow(x_test, y_test), 
         steps_per_epoch=x_train.shape[0] / batch_size,
         epochs=epochs)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_6 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_6 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 32)        9248
#
#  activation_7 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_7 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 64)        18496
#
#  activation_8 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_8 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 64)        36928
#
#  activation_9 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_9 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 128)         73856
#
#  activation_10 (Activation)  (None, 8, 8, 128)         0
#
#  batch_normalization_10 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 128)         147584
#
#  activation_11 (Activation)  (None, 8, 8, 128)         0
#
#  batch_normalization_11 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_7 (Dense)             (None, 10)                20490
#
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/125
# 781/781 [==============================] - 63s 73ms/step - loss: 2.1527 - accuracy: 0.3626 - val_loss: 1.5115 - val_accuracy: 0.5010
# Epoch 2/125
# 781/781 [==============================] - 51s 65ms/step - loss: 1.5052 - accuracy: 0.5165 - val_loss: 1.2276 - val_accuracy: 0.5885
# Epoch 3/125
# 781/781 [==============================] - 51s 66ms/step - loss: 1.2859 - accuracy: 0.5853 - val_loss: 1.2016 - val_accuracy: 0.6371
# Epoch 4/125
# 781/781 [==============================] - 50s 64ms/step - loss: 1.1438 - accuracy: 0.6316 - val_loss: 1.0219 - val_accuracy: 0.6656
# Epoch 5/125
# 781/781 [==============================] - 51s 66ms/step - loss: 1.0443 - accuracy: 0.6621 - val_loss: 0.9432 - val_accuracy: 0.6953
# Epoch 6/125
# 781/781 [==============================] - 50s 64ms/step - loss: 0.9665 - accuracy: 0.6887 - val_loss: 0.8715 - val_accuracy: 0.7195
# Epoch 7/125
# 781/781 [==============================] - 50s 64ms/step - loss: 0.9113 - accuracy: 0.7040 - val_loss: 0.8256 - val_accuracy: 0.7343
# Epoch 8/125
# 781/781 [==============================] - 50s 64ms/step - loss: 0.8689 - accuracy: 0.7178 - val_loss: 0.8267 - val_accuracy: 0.7367
# Epoch 9/125
# 781/781 [==============================] - 50s 64ms/step - loss: 0.8282 - accuracy: 0.7318 - val_loss: 0.7592 - val_accuracy: 0.7545
# Epoch 10/125
# 781/781 [==============================] - 50s 64ms/step - loss: 0.8089 - accuracy: 0.7386 - val_loss: 0.7512 - val_accuracy: 0.7590
# Epoch 11/125
# 781/781 [==============================] - 46s 59ms/step - loss: 0.7846 - accuracy: 0.7468 - val_loss: 0.7290 - val_accuracy: 0.7669
# Epoch 12/125
# 781/781 [==============================] - 46s 59ms/step - loss: 0.7591 - accuracy: 0.7565 - val_loss: 0.6907 - val_accuracy: 0.7782
# Epoch 13/125
# 781/781 [==============================] - 48s 61ms/step - loss: 0.7407 - accuracy: 0.7617 - val_loss: 0.6632 - val_accuracy: 0.7873
# Epoch 14/125
# 781/781 [==============================] - 49s 63ms/step - loss: 0.7213 - accuracy: 0.7696 - val_loss: 0.6729 - val_accuracy: 0.7852
# Epoch 15/125
# 781/781 [==============================] - 46s 58ms/step - loss: 0.6951 - accuracy: 0.7784 - val_loss: 0.6817 - val_accuracy: 0.7868
# Epoch 16/125
# 781/781 [==============================] - 46s 59ms/step - loss: 0.6826 - accuracy: 0.7811 - val_loss: 0.6546 - val_accuracy: 0.7954
# Epoch 17/125
# 781/781 [==============================] - 47s 60ms/step - loss: 0
125
# 781/781 [==============================] - 49s 63ms/step - loss: 0.4481 - accuracy: 0.8745 - val_loss: 0.4818 - val_accuracy: 0.8681
# Epoch 101/125
# 781/781 [==============================] - 49s 62ms/step - loss: 0.4403 - accuracy: 0.8765 - val_loss: 0.4710 - val_accuracy: 0.8684
# Epoch 102/125
# 781/781 [==============================] - 49s 63ms/step - loss: 0.4460 - accuracy: 0.8742 - val_loss: 0.4773 - val_accuracy: 0.8666
# Epoch 103/125
# 781/781 [==============================] - 49s 63ms/step - loss: 0.4485 - accuracy: 0.8736 - val_loss: 0.4755 - val_accuracy: 0.8661
# Epoch 104/125
# 781/781 [==============================] - 48s 62ms/step - loss: 0.4406 - accuracy: 0.8759 - val_loss: 0.4817 - val_accuracy: 0.8674
# Epoch 105/125
# 781/781 [==============================] - 49s 63ms/step - loss: 0.4466 - accuracy: 0.8737 - val_loss: 0.4552 - val_accuracy: 0.8789
# Epoch 106/125
# 781/781 [==============================] - 49s 62ms/step - loss: 0.4458 - accuracy: 0.8754 - val_loss: 0.4637 - val_accuracy: 0.8710
# Epoch 107/125
# 781/781 [==============================] - 49s 62ms/step - loss: 0.4436 - accuracy: 0.8759 - val_loss: 0.4602 - val_accuracy: 0.8713
# Epoch 108/125
# 781/781 [==============================] - 49s 63ms/step - loss: 0.4385 - accuracy: 0.8762 - val_loss: 0.4781 - val_accuracy: 0.8666
# Epoch 109/125
# 781/781 [==============================] - 48s 62ms/step - loss: 0.4413 - accuracy: 0.8755 - val_loss: 0.4696 - val_accuracy: 0.8722
# Epoch 110/125
# 781/781 [==============================] - 49s 62ms/step - loss: 0.4390 - accuracy: 0.8771 - val_loss: 0.4605 - val_accuracy: 0.8719
# Epoch 111/125
# 781/781 [==============================] - 49s 62ms/step - loss: 0.4395 - accuracy: 0.8791 - val_loss: 0.4858 - val_accuracy: 0.8683
# Epoch 112/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.4418 - accuracy: 0.8770 - val_loss: 0.4622 - val_accuracy: 0.8717
# Epoch 113/125
# 781/781 [==============================] - 48s 62ms/step - loss: 0.4369 - accuracy: 0.8776 - val_loss: 0.4764 - val_accuracy: 0.8677
# Epoch 114/125
# 781/781 [==============================] - 49s 62ms/step - loss: 0.4376 - accuracy: 0.8788 - val_loss: 0.4794 - val_accuracy: 0.8705
# Epoch 115/125
# 781/781 [==============================] - 48s 61ms/step - loss: 0.4350 - accuracy: 0.8798 - val_loss: 0.4660 - val_accuracy: 0.8695
# Epoch 116/125
# 781/781 [==============================] - 48s 61ms/step - loss: 0.4319 - accuracy: 0.8798 - val_loss: 0.4629 - val_accuracy: 0.8760
# Epoch 117/125
# 781/781 [==============================] - 47s 60ms/step - loss: 0.4390 - accuracy: 0.8783 - val_loss: 0.4704 - val_accuracy: 0.8689
# Epoch 118/125
# 781/781 [==============================] - 48s 61ms/step - loss: 0.4284 - accuracy: 0.8803 - val_loss: 0.4646 - val_accuracy: 0.8723
# Epoch 119/125
# 781/781 [==============================] - 47s 60ms/step - loss: 0.4397 - accuracy: 0.8774 - val_loss: 0.4676 - val_accuracy: 0.8755
# Epoch 120/125
# 781/781 [==============================] - 47s 61ms/step - loss: 0.4334 - accuracy: 0.8796 - val_loss: 0.4636 - val_accuracy: 0.8751
# Epoch 121/125
# 781/781 [==============================] - 47s 61ms/step - loss: 0.4316 - accuracy: 0.8796 - val_loss: 0.4781 - val_accuracy: 0.8685
# Epoch 122/125
# 781/781 [==============================] - 46s 59ms/step - loss: 0.4337 - accuracy: 0.8798 - val_loss: 0.4741 - val_accuracy: 0.8708
# Epoch 123/125
# 781/781 [==============================] - 47s 61ms/step - loss: 0.4369 - accuracy: 0.8768 - val_loss: 0.4620 - val_accuracy: 0.8705
# Epoch 124/125
# 781/781 [==============================] - 48s 61ms/step - loss: 0.4356 - accuracy: 0.8787 - val_loss: 0.4695 - val_accuracy: 0.8683
# Epoch 125/125
# 781/781 [==============================] - 47s 60ms/step - loss: 0.4291 - accuracy: 0.8803 - val_loss: 0.4545 - val_accuracy: 0.8746

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )

model.save_weights("weights.h5")
